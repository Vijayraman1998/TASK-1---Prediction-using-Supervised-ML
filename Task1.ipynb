# %%
# !!!!!!! TASK 1:- Prediction using Supervised ML !!!!!!!
import pandas as pd  
import numpy as np    
import matplotlib.pyplot as plt

# %%
dataimport = pd.read_csv("http://bit.ly/w-data")

# Successfully imported data from the given data

# %%
# Plotting Data
dataimport.plot(x='Hours', y='Scores', style='o')    
plt.title('Hours vs Scores')    
plt.xlabel('Hours Studied')    
plt.ylabel('Percentage Scores')    
plt.show()

# %%
# dividing the data into attributes

X = dataimport.iloc[:, :-1].values    
y = dataimport.iloc[:, 1].values

# %%
# we use Scikit Learn's builtin method of train_test_split()

from sklearn.model_selection import train_test_split    
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression    
regressor = LinearRegression()    
regressor.fit(X_train, y_train) 
line = regressor.coef_*X+regressor.intercept_ 

# Plotting test data

plt.scatter(X, y)  
plt.plot(X, line);  
plt.show()

# %%
# Question 1) Predict the percentage of an student based on the no. of study hours.
# TEST CASE:~~~~

print(X_test)   
y_pred = regressor.predict(X_test) 
compared = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})    
compared
# Out:
# [[1.5]
#  [3.2]
#  [7.4]
#  [2.5]
#  [5.9]]
#    Actual  Predicted
# 0      20  16.884145
# 1      27  33.732261
# 2      69  75.357018
# 3      30  26.794801
# 4      62  60.491033

# %%
# Question 2) What will be predicted score if a student studies for 9.25 hrs/ day?
hours = [[9.25]] 
predict_scores = regressor.predict(hours)  
print("Number of hours = {}".format(hours))  
print("Prediction Score = {}".format(predict_scores[0]))
# Out:
# Number of hours = [[9.25]]
# Prediction Score = 93.69173248737539
